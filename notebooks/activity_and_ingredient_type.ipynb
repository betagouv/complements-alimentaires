# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Contexte
#
# Les ingredients d'un complément alimentaires sont de différents types dans Teleicare :
# * plante
# * micro-organisme
# * nutriment (forme d'apport de nutriment)
# * arôme
# * additif
# * autre ingrédient actif
# * autre ingrédient
#
#
# **Est-il possible de simplifier la base en associant à chaque type d'ingrédient une activité ?**
# *OUI presque*
# * plante -> actif
# * micro-organisme -> actif
# * nutriment (forme d'apport) -> actif
# * additif -> non actif
# * arôme -> non actif
# * autre ingrédient actif -> cela dépend, à clarifier
# * autre ingrédient -> cela dépend, à clarifier
#
# **En pratique, dans les déclarations, l'activité des ingrédients est-elle modifiée par rapport à celle "par défaut" indiquée dans les tables de référence ?**

# %%
import pandas as pd
import numpy as np

# %%
ingredient_df = pd.read_csv("../../csv-data/REF_ICA_INGREDIENT_AUTRE.csv", encoding="utf-16")
ingredient_df.describe()
# Out:
#         INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT  INGA_ORDRE
# count  1173.000000     1173.000000  1173.000000    1173.000000         0.0
# mean   1283.190111        2.488491     3.164535       1.467178         NaN
# std     346.466307        1.484589     1.382868       0.499134         NaN
# min     691.000000        1.000000     1.000000       1.000000         NaN
# 25%     984.000000        1.000000     2.000000       1.000000         NaN
# 50%    1277.000000        2.000000     4.000000       1.000000         NaN
# 75%    1581.000000        4.000000     4.000000       2.000000         NaN
# max    1887.000000        4.000000     5.000000       2.000000         NaN

# %%
ACTIVITY = {1: "actif", 2: "non actif"}

TYPE = {1: "Nutriment (Forme d'apport)",
2: "Additif",
3: "Arôme",
4: "Autre ingrédient actif",
5: "Autre ingrédient"}

STATUS = {
1: "autorisé",
2: "non autorisé",
3: "à inscrire",
4: "sans objet",
}

# %%
type_and_activity = ingredient_df[['TAING_IDENT', 'FCTINGR_IDENT']]
type_and_activity['type'] = ingredient_df['TAING_IDENT'].apply(lambda x : TYPE[x])
type_and_activity['activity'] = ingredient_df['FCTINGR_IDENT'].apply(lambda x : ACTIVITY[x])
type_and_activity['status'] = ingredient_df['STINGSBS_IDENT'].apply(lambda x : STATUS[x])
type_and_activity
# Out:
#       TAING_IDENT  FCTINGR_IDENT                        type   activity  \
# 0               1              1  Nutriment (Forme d'apport)      actif
# 1               1              1  Nutriment (Forme d'apport)      actif
# 2               1              1  Nutriment (Forme d'apport)      actif
# 3               1              1  Nutriment (Forme d'apport)      actif
# 4               1              1  Nutriment (Forme d'apport)      actif
# ...           ...            ...                         ...        ...
# 1168            4              1      Autre ingrédient actif      actif
# 1169            4              1      Autre ingrédient actif      actif
# 1170            4              1      Autre ingrédient actif      actif
# 1171            5              2            Autre ingrédient  non actif
# 1172            1              1  Nutriment (Forme d'apport)      actif
#
#         status
# 0     autorisé
# 1     autorisé
# 2     autorisé
# 3     autorisé
# 4     autorisé
# ...        ...
# 1168  autorisé
# 1169  autorisé
# 1170  autorisé
# 1171  autorisé
# 1172  autorisé
#
# [1173 rows x 5 columns]

# %% [markdown]
# ### Quelle est l'activité par type d'ingrédient ?

# %%
type_and_activity[['type', 'activity']].groupby(['type', 'activity']).value_counts().to_frame()
# Out:
#                                       count
# type                       activity
# Additif                    non actif    250
# Arôme                      non actif    100
# Autre ingrédient           actif          8
#                            non actif    197
# Autre ingrédient actif     actif        422
#                            non actif      1
# Nutriment (Forme d'apport) actif        195

# %%
# quel est cet "Autre ingrédient actif" qui est non actif ?
ingredient_df[(type_and_activity['activity'] == "non actif") & (type_and_activity['type'] == "Autre ingrédient actif")]

# "Arôme - caramel" => devrait être un arôme
# Out:
#      INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT     INGA_LIBELLE  \
# 861        1562               1            4              2  Arôme - caramel
#
#     INGA_LIBELLE_EN INGA_OBSERVATION INGA_COMMENTAIRE_PUBLIC  \
# 861             NaN              NaN                     NaN
#
#     INGA_COMMENTAIRE_PUBLIC_EN INGA_COMMENTAIRE_PRIVE  \
# 861                        NaN                    NaN
#
#     INGA_COMMENTAIRE_PRIVE_EN INGA_DESCRIPTION INGA_DESCRIPTION_EN  \
# 861                       NaN              NaN                 NaN
#
#      INGA_ORDRE  INGA_OBSOLET
# 861         NaN         False

# %%
# quel sont ces "Autre ingrédient" qui sont actifs ?
ingredient_df[(type_and_activity['activity'] == "actif") & (type_and_activity['type'] == "Autre ingrédient")]
# Out:
#      INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT  \
# 728        1419               1            5              1
# 809        1509               4            5              1
# 810        1510               4            5              1
# 922        1627               4            5              1
# 923        1628               1            5              1
# 929        1634               1            5              1
# 949        1661               1            5              1
# 952        1665               3            5              1
#
#                       INGA_LIBELLE                INGA_LIBELLE_EN  \
# 728          hydrolysat de poisson                            NaN
# 809           Caséinate de calcium                            NaN
# 810                     Ovalbumine                    Egg albumin
# 922                   Argile Beige                            NaN
# 923         Sels Thermaux de Vichy         Thermal salts of Vichy
# 929          Amidon d''orge cireux                            NaN
# 949                   Chlorophylle                    Chlorophyll
# 952  Levure enrichie en vitamine D  Yeast enriched with vitamin D
#
#     INGA_OBSERVATION INGA_COMMENTAIRE_PUBLIC INGA_COMMENTAIRE_PUBLIC_EN  \
# 728              NaN                     NaN                        NaN
# 809              NaN                     NaN                        NaN
# 810              NaN                     NaN                        NaN
# 922              NaN                     NaN                        NaN
# 923              NaN                     NaN                        NaN
# 929              NaN                     NaN                        NaN
# 949              NaN                     NaN                        NaN
# 952              NaN                     NaN                        NaN
#
#     INGA_COMMENTAIRE_PRIVE INGA_COMMENTAIRE_PRIVE_EN INGA_DESCRIPTION  \
# 728                    NaN                       NaN              NaN
# 809                    NaN                       NaN              NaN
# 810                    NaN                       NaN              NaN
# 922                    NaN                       NaN              NaN
# 923                    NaN                       NaN              NaN
# 929                    NaN                       NaN              NaN
# 949                    NaN                       NaN              NaN
# 952                    NaN                       NaN              NaN
#
#     INGA_DESCRIPTION_EN  INGA_ORDRE  INGA_OBSOLET
# 728                 NaN         NaN         False
# 809                 NaN         NaN         False
# 810                 NaN         NaN         False
# 922                 NaN         NaN         False
# 923                 NaN         NaN         False
# 929                 NaN         NaN         False
# 949                 NaN         NaN         False
# 952                 NaN         NaN          True

# %%
# Activité de plantes et micro-organisme
plant_df = pd.read_csv("../../csv-data/REF_ICA_PLANTE.csv", encoding="utf-16")
plant_df.describe()

moorg_df = pd.read_csv("../../csv-data/REF_ICA_MICRO_ORGANISME.csv", encoding="utf-16")
moorg_df.describe()
# Out:
#        MORG_IDENT  FCTINGR_IDENT  STINGSBS_IDENT  MORG_COMMENTAIRE_PUBLIC_EN  \
# count    91.00000           91.0       91.000000                         0.0
# mean     46.00000            1.0        1.032967                         NaN
# std      26.41338            0.0        0.314485                         NaN
# min       1.00000            1.0        1.000000                         NaN
# 25%      23.50000            1.0        1.000000                         NaN
# 50%      46.00000            1.0        1.000000                         NaN
# 75%      68.50000            1.0        1.000000                         NaN
# max      91.00000            1.0        4.000000                         NaN
#
#        MORG_COMMENTAIRE_PRIVE_EN  MORG_ORDRE
# count                        0.0         0.0
# mean                         NaN         NaN
# std                          NaN         NaN
# min                          NaN         NaN
# 25%                          NaN         NaN
# 50%                          NaN         NaN
# 75%                          NaN         NaN
# max                          NaN         NaN

# %%
plant_df['activity'] = plant_df['FCTINGR_IDENT'].apply(lambda x : ACTIVITY[x])

plant_df[['activity']].groupby('activity').value_counts().to_frame()
# Toutes les plantes sont actives
# Out:
#           count
# activity
# actif      1783

# %%
moorg_df['activity'] = moorg_df['FCTINGR_IDENT'].apply(lambda x : ACTIVITY[x])

moorg_df[['activity']].groupby('activity').value_counts().to_frame()# Tous les microorganismes sont actifs
# Out:
#           count
# activity
# actif        91

# %% [markdown]
# ### Quel est le status (autorisé ou non) par type d'ingrédient ?

# %%
type_and_activity[['type', 'status']].groupby(['type', 'status']).value_counts().to_frame()

# TODO Est-ce qu'il y a aussi des sans objets dans les Plantes et Microorganismes
# Out:
#                                          count
# type                       status
# Additif                    autorisé          3
#                            non autorisé      2
#                            sans objet      245
# Arôme                      autorisé          4
#                            sans objet       96
# Autre ingrédient           autorisé         19
#                            non autorisé      1
#                            sans objet      184
#                            à inscrire        1
# Autre ingrédient actif     autorisé        354
#                            non autorisé     21
#                            sans objet       47
#                            à inscrire        1
# Nutriment (Forme d'apport) autorisé        193
#                            non autorisé      2

# %%
# Les valeurs singulières
ingredient_df[(type_and_activity['status'] == 'non autorisé') & (type_and_activity['type'] == 'Nutriment (Forme d\'apport)')]
# Out:
#       INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT  \
# 1007        1720               2            1              1
# 1162        1877               2            1              1
#
#                   INGA_LIBELLE        INGA_LIBELLE_EN INGA_OBSERVATION  \
# 1007                    Soufre                 Sulfur              NaN
# 1162  L-thréonate de magnésium  Magnesium L-Threonate              NaN
#
#                                 INGA_COMMENTAIRE_PUBLIC  \
# 1007  Le soufre n'est pas autorisé par la directive ...
# 1162                                                NaN
#
#      INGA_COMMENTAIRE_PUBLIC_EN INGA_COMMENTAIRE_PRIVE  \
# 1007                        NaN                    NaN
# 1162                        NaN                    NaN
#
#      INGA_COMMENTAIRE_PRIVE_EN INGA_DESCRIPTION INGA_DESCRIPTION_EN  \
# 1007                       NaN              NaN                 NaN
# 1162                       NaN              NaN                 NaN
#
#       INGA_ORDRE  INGA_OBSOLET
# 1007         NaN          True
# 1162         NaN         False

# %%
ingredient_df[(type_and_activity['status'] == 'non autorisé') & (type_and_activity['type'] == 'Autre ingrédient actif')]
# Out:
#       INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT  \
# 355         1046               2            4              1
# 356         1047               2            4              1
# 357         1048               2            4              1
# 358         1049               2            4              1
# 359         1050               2            4              1
# 360         1051               2            4              1
# 361         1052               2            4              1
# 362         1053               2            4              1
# 364         1055               2            4              1
# 365         1056               2            4              1
# 366         1057               2            4              1
# 367         1058               2            4              1
# 368         1059               2            4              1
# 369         1060               2            4              1
# 370         1061               2            4              1
# 784         1482               2            4              1
# 798         1497               2            4              1
# 894         1597               2            4              1
# 939         1650               2            4              1
# 942         1654               2            4              1
# 1130        1845               2            4              1
#
#                           INGA_LIBELLE                   INGA_LIBELLE_EN  \
# 355                           Agmatine                               NaN
# 356                     Clinoptilolite                               NaN
# 357                       Glycocyamine                               NaN
# 358                  Indole-3-carbinol                               NaN
# 359                        Ipriflavone                               NaN
# 360                        Méthylamine                               NaN
# 361                    Méthylcellulose                               NaN
# 362                       Noréphédrine                               NaN
# 364                       Prégnénolone                               NaN
# 365                         Sérotonine                               NaN
# 366                     Splénoplentine                               NaN
# 367                          Stachyose                               NaN
# 368                       Thymopentine                               NaN
# 369                        Vinpocétine                               NaN
# 370                            Zéolite                           Zeolite
# 784                 Terre de diatomées                               NaN
# 798     Bioflavonoïdes de pamplemousse          Grapefruit bioflavonoids
# 894                       Serrapeptase                 Serratiopeptidase
# 939                  Méthoxyisoflavone                 Méthoxyisoflavone
# 942                        Nattokinase                       Nattokinase
# 1130  L-alpha-glycérophosphorylcholine  L-alpha-Glycerophosphorylcholine
#
#      INGA_OBSERVATION                            INGA_COMMENTAIRE_PUBLIC  \
# 355               NaN                                                NaN
# 356               NaN                                                NaN
# 357               NaN                                                NaN
# 358               NaN                                                NaN
# 359               NaN                                                NaN
# 360               NaN                                                NaN
# 361               NaN                                                NaN
# 362               NaN                                                NaN
# 364               NaN                                                NaN
# 365               NaN                                                NaN
# 366               NaN                                                NaN
# 367               NaN                                                NaN
# 368               NaN                                                NaN
# 369               NaN                                                NaN
# 370               NaN                                                NaN
# 784               NaN                                                NaN
# 798               NaN  Les bioflavonoïdes de pamplemousse purifiés, u...
# 894               NaN   La Serrapeptase est un Novel Food non autorisé.
# 939               NaN  Cet ingrédient un nouvel ingrédient et doit fa...
# 942               NaN                                  Nouvel ingrédient
# 1130              NaN  Ingrédient considéré comme nouveau - voir Nove...
#
#      INGA_COMMENTAIRE_PUBLIC_EN  \
# 355                         NaN
# 356                         NaN
# 357                         NaN
# 358                         NaN
# 359                         NaN
# 360                         NaN
# 361                         NaN
# 362                         NaN
# 364                         NaN
# 365                         NaN
# 366                         NaN
# 367                         NaN
# 368                         NaN
# 369                         NaN
# 370                         NaN
# 784                         NaN
# 798                         NaN
# 894                         NaN
# 939                         NaN
# 942                         NaN
# 1130                        NaN
#
#                                  INGA_COMMENTAIRE_PRIVE  \
# 355                                                 NaN
# 356                                                 NaN
# 357                                                 NaN
# 358                                                 NaN
# 359                                                 NaN
# 360                                                 NaN
# 361                                                 NaN
# 362                                                 NaN
# 364                                                 NaN
# 365                                                 NaN
# 366                                                 NaN
# 367                                                 NaN
# 368                                                 NaN
# 369                                                 NaN
# 370   Novel Food - aucune demande d'autorisation dép...
# 784   En l''absence d''information, cet ingrédient e...
# 798   Faire la différence entre un extrait de pépins...
# 894    La Serrapeptase est un Novel Food non autorisé.
# 939                                                 NaN
# 942   http://www.hc-sc.gc.ca/dhp-mps/prodnatur/legis...
# 1130  Wikipedia : La L-a-glycérophosphorylcholine, é...
#
#                               INGA_COMMENTAIRE_PRIVE_EN  \
# 355                                                 NaN
# 356                                                 NaN
# 357                                                 NaN
# 358                                                 NaN
# 359                                                 NaN
# 360                                                 NaN
# 361                                                 NaN
# 362                                                 NaN
# 364                                                 NaN
# 365                                                 NaN
# 366                                                 NaN
# 367                                                 NaN
# 368                                                 NaN
# 369                                                 NaN
# 370   Novel Food catalogue : Zeolites refer to a gro...
# 784                                                 NaN
# 798                                                 NaN
# 894                                                 NaN
# 939                                                 NaN
# 942                                                 NaN
# 1130                                                NaN
#
#                                        INGA_DESCRIPTION INGA_DESCRIPTION_EN  \
# 355                                                 NaN                 NaN
# 356                                                 NaN                 NaN
# 357                                                 NaN                 NaN
# 358                                                 NaN                 NaN
# 359                                                 NaN                 NaN
# 360                                                 NaN                 NaN
# 361                                                 NaN                 NaN
# 362                                                 NaN                 NaN
# 364                                                 NaN                 NaN
# 365                                                 NaN                 NaN
# 366                                                 NaN                 NaN
# 367                                                 NaN                 NaN
# 368                                                 NaN                 NaN
# 369                                                 NaN                 NaN
# 370                                                 NaN                 NaN
# 784                                                 NaN                 NaN
# 798                                                 NaN                 NaN
# 894   La serrapeptase ou Serratiopeptidase (Serratia...                 NaN
# 939                                                 NaN                 NaN
# 942                                                 NaN                 NaN
# 1130                                                NaN                 NaN
#
#       INGA_ORDRE  INGA_OBSOLET
# 355          NaN         False
# 356          NaN         False
# 357          NaN         False
# 358          NaN         False
# 359          NaN         False
# 360          NaN         False
# 361          NaN         False
# 362          NaN         False
# 364          NaN         False
# 365          NaN         False
# 366          NaN         False
# 367          NaN         False
# 368          NaN         False
# 369          NaN         False
# 370          NaN         False
# 784          NaN         False
# 798          NaN         False
# 894          NaN         False
# 939          NaN         False
# 942          NaN         False
# 1130         NaN         False

# %%
ingredient_df[(type_and_activity['status'] == 'non autorisé') & (type_and_activity['type'] == 'Additif')]
# Out:
#       INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT INGA_LIBELLE  \
# 426         1117               2            2              2         E171
# 1097        1812               2            2              2         E127
#
#      INGA_LIBELLE_EN INGA_OBSERVATION  \
# 426             E171              NaN
# 1097            E127              NaN
#
#                                 INGA_COMMENTAIRE_PUBLIC  \
# 426   Additif interdit en UE depuis 2022 (https://eu...
# 1097  Cet additif n'est pas autorisé dans les complé...
#
#      INGA_COMMENTAIRE_PUBLIC_EN  \
# 426                         NaN
# 1097                        NaN
#
#                                  INGA_COMMENTAIRE_PRIVE  \
# 426   Groupe II : quantum satis / CA solide, liquide...
# 1097  Ne figure pas dans les additifs autorisés pour...
#
#      INGA_COMMENTAIRE_PRIVE_EN            INGA_DESCRIPTION  \
# 426                        NaN                         NaN
# 1097                       NaN  Colorant rouge synthétique
#
#      INGA_DESCRIPTION_EN  INGA_ORDRE  INGA_OBSOLET
# 426                  NaN         NaN         False
# 1097                 NaN         NaN         False

# %% [markdown]
# => certains additifs étant interdits, il faudrait devoir redéclarer à chaque changement d'additifs

# %%
ingredient_df[(type_and_activity['status'] == 'autorisé') & (type_and_activity['type'] == 'Arôme')]
# Out:
#       INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT  \
# 746         1441               1            3              2
# 747         1442               1            3              2
# 748         1443               1            3              2
# 1055        1768               1            3              2
#
#                INGA_LIBELLE INGA_LIBELLE_EN INGA_OBSERVATION  \
# 746          arôme - menthe             NaN              NaN
# 747         Arôme grenadine             NaN              NaN
# 748          Arôme - mangue             NaN              NaN
# 1055  arôme clou de girofle     clove aroma              NaN
#
#      INGA_COMMENTAIRE_PUBLIC INGA_COMMENTAIRE_PUBLIC_EN  \
# 746                      NaN                        NaN
# 747                      NaN                        NaN
# 748                      NaN                        NaN
# 1055                     NaN                        NaN
#
#      INGA_COMMENTAIRE_PRIVE INGA_COMMENTAIRE_PRIVE_EN INGA_DESCRIPTION  \
# 746                     NaN                       NaN              NaN
# 747                     NaN                       NaN              NaN
# 748                     NaN                       NaN              NaN
# 1055                    NaN                       NaN              NaN
#
#      INGA_DESCRIPTION_EN  INGA_ORDRE  INGA_OBSOLET
# 746                  NaN         NaN         False
# 747                  NaN         NaN         False
# 748                  NaN         NaN         False
# 1055                 NaN         NaN         False

# %% [markdown]
# => le fait que les arômes soient tous autorisés ou sans objet fait pencher pour dire qu'il n'y a pas besoin de refaire une déclaration pour 2 arômes différents ?
# ou permettre une déclaration, qui ne passe pas par le processus d'instruction mais qui vient remplir la BDD de tous les CA disponibles en France
#
# Y-a t'il une nécessité légale à la redéclaration ?

# %% [markdown]
# il pourrait y avoir une uniformisaiont de l'écriture des nom d'arômes :
# - sans tiret entre 'arôme' et son nom

# %%
plant_df['status'] = plant_df['STINGSBS_IDENT'].apply(lambda x : STATUS[x])

plant_df[['status']].groupby('status').value_counts().to_frame()
# Out:
#               count
# status
# autorisé       1013
# non autorisé    591
# à inscrire      179

# %%
moorg_df['status'] = moorg_df['STINGSBS_IDENT'].apply(lambda x : STATUS[x])

moorg_df[['status']].groupby('status').value_counts().to_frame()
# Out:
#             count
# status
# autorisé       90
# sans objet      1

# %%
moorg_df[moorg_df['status'] == 'sans objet']
# Out:
#     MORG_IDENT  FCTINGR_IDENT  STINGSBS_IDENT MORG_ESPECE  \
# 84          85              1               4     faecium
#
#    MORG_COMMENTAIRE_PUBLIC  MORG_COMMENTAIRE_PUBLIC_EN MORG_COMMENTAIRE_PRIVE  \
# 84                     NaN                         NaN                    NaN
#
#     MORG_COMMENTAIRE_PRIVE_EN  MORG_ORDRE  MORG_OBSOLET    MORG_GENRE  \
# 84                        NaN         NaN         False  Enterococcus
#
#    activity      status
# 84    actif  sans objet

# %% [markdown]
# ### Faudra t'il nettoyer les Arômes, Additifs, Formes d'apport et Autre ingrédients ?

# %%
ingredient_df[(type_and_activity['type'] == "Nutriment (Forme d'apport)")]["INGA_DESCRIPTION"].dropna()
# "INGA_OBSERVATION" est vide pour tous
# "INGA_OBSERVATION_EN" est vide pour tous
# Monométhylsilanetriol à pour synonyme et pour description "Silicium organique" TODO : ne conserver que l'un des deux
# Out:
# 910     eaux mères riches en magnésium grâce à l évapo...
# 1034                                   Silicium organique
# 1098    Nouvel aliment autorisé - forme synthétique du...
# 1124    Nouvel ingrédient autorisé puis intégré à l'an...
# 1134    Le nouvel aliment est le fructoborate de calci...
# 1149    Spécifications Novel Food : La levure de boula...
# 1150    Le tartrate-adipate d’hydroxyde de fer (IHAT) ...
# Name: INGA_DESCRIPTION, dtype: object

# %%
ingredient_df[(type_and_activity['type'] == "Nutriment (Forme d'apport)")]["INGA_LIBELLE"]
# Levure de boulanger (Saccha romyces cerevisiae) traitée par UV à corriger orthographe
# redondant avec Levure enrichie en vitamine D qui lui est de type "Autre ingrédient (normalement non actif)" mais avec une activité "actif"
# TODO: sont-ils tous bien liés à la substance qu'il faut
# Out:
# 910     eaux mères riches en magnésium grâce à l évapo...
# 1034                                   Silicium organique
# 1098    Nouvel aliment autorisé - forme synthétique du...
# 1124    Nouvel ingrédient autorisé puis intégré à l'an...
# 1134    Le nouvel aliment est le fructoborate de calci...
# 1149    Spécifications Novel Food : La levure de boula...
# 1150    Le tartrate-adipate d’hydroxyde de fer (IHAT) ...
# Name: INGA_DESCRIPTION, dtype: object

# %%
pd.set_option('display.max_rows', 500)
## TODO Hypothèse à vérifier : Les autres ingrédients actifs ce sont les ingrédients substance (qui ont leur doublon en tant que substance)
## sauf exception type huile de hareng
## Certaines ["INGA_DESCRIPTION"] sont des CAS number
# triplon Huile de Krill ingr Euphausia superba ingr et Huile de Krill substance
# Lait d'annesse ing et lait d'annesse substance
# miel d''acacia ing et miel d'acacia
# peptide d''élastine ing et peptide d'elastine subst et oligopeptide d'elastine subs
# huile de foie de morues ing et huile de foie de morue ing et huile de foie de morue subs
# Fibres ing et Fibres subst et Fibres d''agrumes ing et Fibres de pommes ing et Fibres d'acacia
# 'huile de TCM (triglycérides à chaînes moyennes)' vs 'Triglycérides à chaine moyenne'
aia_df = ingredient_df[(type_and_activity['type'] == "Autre ingrédient actif")]["INGA_LIBELLE"]

aia_df
# Out:
# 184                                       Acétylcarnitine
# 185                                        Acétylcystéine
# 186                                      Acétylméthionine
# 187                       Acide adénosine-5'-phosphorique
# 188                            Acide alpha-aminobutyrique
# 189                                      Acide aspartique
# 190                    Acide cytidine-5'-monophosphorique
# 191                            Acide gamma-aminobutyrique
# 192                                      Acide glutamique
# 193                       Acide guanosine-5'-phosphorique
# 194                                    Acide hyaluronique
# 195                         Acide inosine-5'-phosphorique
# 196                             Acide linoléique conjugué
# 197                                        Acide lipoïque
# 198                                        Acide orotique
# 199                             Acide para-aminobenzoïque
# 200                                       Acide pyruvique
# 201                         Acide uridine-5'-phosphorique
# 202                                               Alanine
# 203                                   Alpha-cétoglutarate
# 204                       Alpha-cétoglutarate d'ornithine
# 205                                   Alpha-galactosidase
# 206                                    Alpha-lactalbumine
# 207                                               Amylase
# 208                                     Arabinogalactanes
# 209                                        Arabinoxylanes
# 210                                              Arginine
# 211                                            Asparagine
# 212                                             Aspartate
# 213                                          Astaxanthine
# 214                                          Bêta-alanine
# 215                                    Bêta-cyclodextrine
# 216                                          Bêtaglucanes
# 217                                               Bétaïne
# 218                                 Bitartrate de choline
# 219                                            Bromélaïne
# 220                                               Caféine
# 221                                             Carnitine
# 222                                             Carnosine
# 223                                   Cartilage de requin
# 224                                               Caséine
# 225                                               Chitine
# 226                                       Chitine-glucane
# 227                                              Chitosan
# 228                           Chlorhydrate de glucosamine
# 229            Chlorhydrate d'ester éthylique de créatine
# 230                                   Chlorure de choline
# 231                                               Choline
# 232                                          Chondroïtine
# 233                                         Chymotrypsine
# 234                                    Citrate de choline
# 235                                   Citrate de créatine
# 236                                               Citrine
# 237                                            Citrulline
# 238                                Coquille Saint-Jacques
# 239                                              Créatine
# 240                                  Créatine monohydrate
# 241                                             Curcumine
# 242                                              Cystéine
# 243                                               Cystine
# 244                                              Diastase
# 245                                  Dimethylaminoéthanol
# 246                               Fructo-oligosaccharides
# 247                              Galacto-oligosaccharides
# 248                                          Gelée royale
# 249                                          Glucomannane
# 250                                 Gluconate de créatine
# 251                                           Glucosamine
# 252                                      Glucuronolactone
# 253                                             Glutamine
# 254                                            Glutathion
# 255                                               Glycine
# 256                                         Hémicellulose
# 257                                           Hespéridine
# 258                                             Histidine
# 259                                      Huile de poisson
# 260                                                Huître
# 261                              Hydrolysat de petit lait
# 262                               Hydrolysat de protéines
# 263                 Hydrolysat de protéines de lactosérum
# 264                                 Hydroxyméthylbutyrate
# 265                                        Hydroxytyrosol
# 266                                               Inosine
# 267                                              Inositol
# 268                                               Inuline
# 269                                             Invertase
# 270                            Isolat de protéine de lait
# 271                                            Isoleucine
# 272                                          Isomaltulose
# 273                                               Lactase
# 274                                              Lactitol
# 275                                          Lactoferrine
# 276                                            Lactosérum
# 277                                             Lactulose
# 278                                           L-carnitine
# 279                                             Lécithine
# 280                                               Leptine
# 281                                               Leucine
# 282                                                Lipase
# 283                                               Lutéine
# 284                                              Lycopène
# 285                                                Lysine
# 286                                                Malate
# 287                                Malate de tri-créatine
# 288                                               Maltase
# 289                                              Mannitol
# 290                                               Mannose
# 291                                            Mélatonine
# 292                                            Méthionine
# 293                            Méthylsulfonate de méthane
# 294                                      Minéraux du lait
# 295                               Monohydrate de créatine
# 296                                   N-acétylglucosamine
# 297                   Nicotinamide adénine déshydrogénase
# 298             Nicotinamide adénine dinucléotide réduite
# 299                                         Oligofructose
# 300                                             Ornithine
# 301                                          Os de seiche
# 302                                           Pancréatine
# 303                                               Papaïne
# 304                                             Pectinase
# 305                                              Pectines
# 306                                               Pepsine
# 307                                         Phénylalanine
# 308                                   Phosphatidylcholine
# 309                              Phosphatidyléthanolamine
# 310                                  Phosphatidylinositol
# 311                                    Phosphatidylsérine
# 312                                        Phospholipides
# 313                                         Phosphosérine
# 314                                          Phycocyanine
# 315                                          Phytostanols
# 316                                          Phytostérols
# 317                                               Pinitol
# 318                                          Policosanols
# 319                                                Pollen
# 320                                  Poudre de lactosérum
# 321                                Poudre d'œuf de caille
# 322                                   Poudre d'œuf entier
# 323                                               Proline
# 324                                              Protéase
# 325                                Protéine de lactosérum
# 326                                      Protéine de lait
# 327                                Protéine de petit-lait
# 328                                      Protéine de soja
# 329                                             Protéines
# 330                                              Pyruvate
# 331                                  Pyruvate de créatine
# 332                                            Quercétine
# 333                                           Resvératrol
# 334                                                Ribose
# 335                                              Rutoside
# 336                                           Saccaharase
# 337                                                Sérine
# 338                                               Sucrase
# 339                               Sulfate de chondroïtine
# 340                                Sulfate de glucosamine
# 341                                  Superoxyde dismutase
# 342                                               Taurine
# 343                                              Théanine
# 344                                             Thréonine
# 345                        Triglycérides à chaine moyenne
# 346                                    Triméthylglycérine
# 347                                              Trypsine
# 348                                           Tryptophane
# 349                                              Tyrosine
# 350                                            Ubiquinone
# 351                                                Valine
# 352                                         Violaxanthine
# 353                                              Xylanase
# 354                                           Zéaxanthine
# 355                                              Agmatine
# 356                                        Clinoptilolite
# 357                                          Glycocyamine
# 358                                     Indole-3-carbinol
# 359                                           Ipriflavone
# 360                                           Méthylamine
# 361                                       Méthylcellulose
# 362                                          Noréphédrine
# 363                                             Norvaline
# 364                                          Prégnénolone
# 365                                            Sérotonine
# 366                                        Splénoplentine
# 367                                             Stachyose
# 368                                          Thymopentine
# 369                                           Vinpocétine
# 370                                               Zéolite
# 650                                huile de foie de morue
# 657       huile de TCM (triglycérides à chaînes moyennes)
# 685                                                  miel
# 730                                              Propolis
# 732                                   Collagène hydrolysé
# 735                                              Kératine
# 736                                Hydrolysat de kératine
# 737                                             Colostrum
# 740                              Gelée royale lyophilisée
# 742                                       Fibres de pomme
# 743                     N,N-Diméthylglycine hydrochloride
# 749                        L-Arginine-alpha-cétoglutarate
# 750                               L-Carnitine L-Tartrate
# 752                                       Charbon végétal
# 754                                               Rutine
# 755                                       Collagène marin
# 760                        Arêtes de poissons hydrolysées
# 769                                      Protéine de pois
# 775                                            Eau de mer
# 777                                          Glucoamylase
# 782                                                Corail
# 784                                    Terre de diatomées
# 785                             Fibres solubles d''acacia
# 786                                       Huile de coprah
# 788                                                 Nacre
# 789                               Protéines de lactosérum
# 790                           Poudre de calcium de corail
# 792                                              dextrine
# 793                                   N-acétyl L-tyrosine
# 796                                            Citicoline
# 798                        Bioflavonoïdes de pamplemousse
# 799                               huile de foie de requin
# 801                                                Fibres
# 802                                       Fibres solubles
# 803                                     Fibres insolubles
# 804                               Fibres solubles de maïs
# 808                                  Poudre blanc d''oeuf
# 815                                         Hydroxylysine
# 816                                        Hydroxyproline
# 819                                   Laitance de poisson
# 822                                huile de germes de blé
# 825                             Glucosamine sulfate 2 KCl
# 826                                      Huile de périlla
# 828                                        Huile de Krill
# 829                             Chlorhydrate de berbérine
# 830                                       oeufs de hareng
# 831                                      Oeufs de poisson
# 832                                   Cartilage hydrolysé
# 838                                 Hydrolysat de caséine
# 840                               Protéines de petit lait
# 842                            Huile de pandalus borealis
# 844                                              Escargot
# 851                                     Perna canaliculus
# 853                       Huile d''anchois et de sardines
# 854                              Pyroglutamate L-arginine
# 856                                             Cellulase
# 859                                     Vinaigre de cidre
# 860                                    Coquille d’huître
# 861                                       Arôme - caramel
# 862                                        miel d''acacia
# 863                                         miel d’acacia
# 869                                             L-cystine
# 870                                   L-citrulline malate
# 872                               Fumarate de L-carnitine
# 873                          Argile verte montmorillonite
# 874                                              Hydromel
# 878                                L-5-Hydroxytryptophane
# 879                                  5-hydroxytryptophane
# 880                            Chlorhydrate de L-arginine
# 882                                              Dolomite
# 884                                     Cartilage de raie
# 885                                      Membrane d''oeuf
# 889                                 inositolhéxaphosphate
# 894                                          Serrapeptase
# 895                                            Diosmétine
# 896                                              Diosmine
# 897                           Dichlorhydrate de carcinine
# 898                 Chlorhydrate de propionyl L-carnitine
# 900                    Chlorhydrate d''acétyl-L-carnitine
# 902                        Alpha-cétoglutarate de calcium
# 903         Sel disodique de l''adénosine 5’-triphosphate
# 907                                   Peptide d''élastine
# 908                                              Elastine
# 909                                       Acide L-malique
# 912                                           L-Glutamine
# 918                                        lait de jument
# 921                                Chlorhydrate de lysine
# 927            Hydrolysat enzymatique de protéines de riz
# 930                                         Hémicellulase
# 931                                        Argile blanche
# 932                                       Chair d''huître
# 933                                Huile de graine de lin
# 934                             Hydroxyapatite de calcium
# 939                                     Méthoxyisoflavone
# 941                               S-Adenosyl-L-Méthionine
# 942                                           Nattokinase
# 943                            Huile de Schizochytrium sp
# 944                                     Fibres d''agrumes
# 946                                 Hyaluronate de sodium
# 950                           Chlorhydrate de L-ornithine
# 951                                   Gamma-cyclodextrine
# 957                                              Shilajit
# 958                              Oligo-proanthocyanidines
# 959                             Levure de bière inactivée
# 960                               Huile de foie de morues
# 961                                      Fibres de seigle
# 963                                      Citroflavonoïdes
# 964                           Chlorhydrate de L-cystéine
# 965                              Isomalto-oligosaccharide
# 966                      Hydrolysat des protéines bovines
# 967                     Hydrolysat de protéines de poulet
# 969                                L-arginine éthyl ester
# 970                                   Alpha-cyclodextrine
# 971                               Huile anchois - sardine
# 972                           Chlorhydrate de L-Histidine
# 973                           Créatine ethyl ester malate
# 975                                          L-isoleucine
# 976                                             L-leucine
# 977                                              L-valine
# 978                             R-alpha lipoate de sodium
# 979                                             Collagène
# 980                                   Collagène de poulet
# 982                                        Anas barbariae
# 983                              Chlorhydrate de créatine
# 984                                      Créatine nitrate
# 985                                 Phosphate de créatine
# 986                          Créatine alpha-ketoglutarate
# 987                                      Pectine de pomme
# 991                                             Aragonite
# 992                                        Gamma-oryzanol
# 993                              Huile de foie de chimère
# 994                                 Eau de coco en poudre
# 995                                         Lait d anesse
# 997                                      lait de chamelle
# 998                                              Pipérine
# 1006                              L-ornithine L-aspartate
# 1013                                     huile de saumon
# 1014                                      L-Ornithine HCL
# 1015                           Moule perlière d eau douce
# 1020                                 L-alanyl-L-glutamine
# 1021                                       Bêta-glucanase
# 1022                                            Peptidase
# 1023                                              Phytase
# 1025                                Prolyl-oligopeptidase
# 1026                          Chlorhydrate de L-carnitine
# 1029                                            Adénosine
# 1030                                            Guanosine
# 1031                                             Cytidine
# 1032                                              Uridine
# 1038                                 aspartate d'arginine
# 1039                                                garum
# 1046                                  Peptides de poisson
# 1048                                      Fibres d'avoine
# 1050                                 N-acétyl-L-glutamine
# 1052                                     huile de calanus
# 1054                                    L-arginine malate
# 1057                          Extrait riche en taxifoline
# 1058                 Extrait des racines de trois plantes
# 1059                          Fibres solubles de fenugrec
# 1061                                        Phlorotannins
# 1062                                     D-chiro inositol
# 1063                                         Myo-inositol
# 1065                                Palmitoyléthanolamide
# 1070                                      Acide férulique
# 1071                                 Caprylate de calcium
# 1072              Sel disodique pyrroloquinoléine-quinone
# 1075                               Gluco-oligosaccharides
# 1078                                    2'-fucosyllactose
# 1079                                     Protéines de riz
# 1080                                            Céramides
# 1081                                  Caséinate de sodium
# 1082                                 Cartilage de poulet
# 1084                        Hydrolysat de collagène bovin
# 1085                   Hydrolysat de collagène de poisson
# 1086                                     Acides fulviques
# 1087                                          Troxérutine
# 1088                                      L-ergothionéine
# 1089                                             Catalase
# 1091                                              Oxydase
# 1092                                          Phosphatase
# 1093                                          Homotaurine
# 1094                                          Tributyrine
# 1096                                   Citrate de bétaïne
# 1099                       hydrolysat de gélatine de porc
# 1102           Sel disodique de pyrroloquinoléine-quinone
# 1103                                            Ubiquinol
# 1104                              Monolaurate de glycérol
# 1106                                     Phénylcapsaïcine
# 1107                   Bitartrate de diméthylaminoéthanol
# 1108                                       Pain d'abeille
# 1109                            Extrait de pain d'abeille
# 1112                                         Caroténoïdes
# 1114                    Extrait protéique de rein de porc
# 1115                   Lactobacillus acidophilus inactivé
# 1116                         Lactobacillus casei inactivé
# 1117                     Lactobacillus rhamnosus inactivé
# 1120                                               Xylose
# 1123                                                Natto
# 1125                                     Huile de calamar
# 1126                                   Mélange de légumes
# 1128                                       miel de Manuka
# 1129    Extrait des racines de trois plantes (Cynanchu...
# 1130                     L-alpha-glycérophosphorylcholine
# 1132                     Chlorophylline de cuivre sodique
# 1133                     Lactobacillus plantarum inactivé
# 1135                                     3-Fucosyllactose
# 1136                                  Acides gras cétylés
# 1137                                               Levain
# 1138                     Acide alpha-hydroxy-isocaproïque
# 1139                      Hydrolysat de protéines de porc
# 1140                      Hydrolysat de collagène de porc
# 1141                                Xylo-oligosaccharides
# 1142                      Bifidobacterium Lactis inactivé
# 1143          Inactivated Bifidobacterium Lactis inactivé
# 1144                     Bifidobacterium lactis inactivée
# 1145                              Tétrahydrocurcuminoïdes
# 1146                                   Butyrate de sodium
# 1147    Biomasse d'Aspergillus oryzae enrichie en miné...
# 1148                     Bifidobacterium bifidum inactivé
# 1151                              Extrait de crête de coq
# 1152                     Bifidobacterium lactis inactivés
# 1153           flavonoïdes issus de Glycyrrhiza glabra L.
# 1154                              Huile de foie de flétan
# 1155                                     Acide palmitique
# 1156                                        Acide oléique
# 1157                                  Acide palmitoléique
# 1158                                      Acide stéarique
# 1159                                    Palaemon serratus
# 1160                                   Euphausia superba
# 1161                                       Cervus elaphus
# 1163                                    Pandalus borealis
# 1164                                  Caprylate de sodium
# 1167                         Chondroïtine sulfate sodique
# 1168       isoflavones issues de Glycine max. (L.) Merr.
# 1169                              acide gamma-linolénique
# 1170                                      Huile de hareng
# Name: INGA_LIBELLE, dtype: object

# %%
pd.set_option('display.max_rows', 250)

additif_df = ingredient_df[(type_and_activity['type'] == "Additif")]['INGA_LIBELLE']
additif_df
#  hydroxypropyl méthyl cellulose
#  citrate de calcium
#  vinaigre d''alcool
#  stévia
# Out:
# 371                               E100
# 372                               E101
# 373                               E102
# 374                               E104
# 375                               E110
# 376                              E1103
# 377                               E120
# 378                              E1200
# 379                              E1201
# 380                              E1202
# 381                              E1203
# 382                              E1204
# 383                              E1205
# 384                              E1206
# 385                              E1207
# 386                              E1208
# 387                              E1209
# 388                               E122
# 389                               E124
# 390                               E129
# 391                               E131
# 392                               E132
# 393                               E133
# 394                               E140
# 395                              E1404
# 396                               E141
# 397                              E1410
# 398                              E1412
# 399                              E1413
# 400                              E1414
# 401                               E142
# 402                              E1420
# 403                              E1422
# 404                              E1440
# 405                              E1442
# 406                              E1450
# 407                              E1451
# 408                              E1505
# 409                              E150a
# 410                              E150b
# 411                              E150c
# 412                              E150d
# 413                               E151
# 414                              E1521
# 415                               E153
# 416                               E155
# 417                              E160a
# 418                              E160b
# 419                              E160c
# 420                              E160d
# 421                              E160e
# 422                              E161b
# 423                               E162
# 424                               E163
# 425                               E170
# 426                               E171
# 427                               E172
# 428                               E200
# 429                               E202
# 430                               E203
# 431                               E210
# 432                               E211
# 433                               E212
# 434                               E213
# 435                               E260
# 436                               E261
# 437                               E262
# 438                               E263
# 439                               E270
# 440                               E290
# 441                               E296
# 442                               E300
# 443                               E301
# 444                               E302
# 445                               E304
# 446                               E306
# 447                               E307
# 448                               E308
# 449                               E309
# 450                               E310
# 451                               E311
# 452                               E312
# 453                               E319
# 454                               E320
# 455                               E321
# 456                               E322
# 457                               E325
# 458                               E326
# 459                               E327
# 460                               E330
# 461                               E331
# 462                               E332
# 463                               E333
# 464                               E334
# 465                               E335
# 466                               E336
# 467                               E337
# 468                               E338
# 469                               E339
# 470                               E340
# 471                               E341
# 472                               E343
# 473                               E350
# 474                               E351
# 475                               E352
# 476                               E354
# 477                               E380
# 478                               E392
# 479                               E400
# 480                               E401
# 481                               E402
# 482                               E403
# 483                               E404
# 484                               E405
# 485                               E406
# 486                               E407
# 487                              E407a
# 488                               E410
# 489                               E412
# 490                               E413
# 491                               E414
# 492                               E415
# 493                               E416
# 494                               E417
# 495                               E418
# 496                               E420
# 497                               E422
# 498                               E425
# 499                               E426
# 500                               E432
# 501                               E433
# 502                               E434
# 503                               E435
# 504                               E436
# 505                               E440
# 506                               E450
# 507                               E451
# 508                               E452
# 509                               E459
# 510                               E460
# 511                               E461
# 512                               E462
# 513                               E463
# 514                               E464
# 515                               E465
# 516                               E466
# 517                               E468
# 518                               E469
# 519                              E470a
# 520                              E470b
# 521                               E471
# 522                              E472a
# 523                              E472b
# 524                              E472c
# 525                              E472d
# 526                              E472e
# 527                              E472f
# 528                               E473
# 529                               E474
# 530                               E475
# 531                               E491
# 532                               E492
# 533                               E493
# 534                               E494
# 535                               E495
# 536                               E500
# 537                               E501
# 538                               E503
# 539                               E504
# 540                               E507
# 541                               E508
# 542                               E509
# 543                               E511
# 544                               E513
# 545                               E514
# 546                               E515
# 547                               E516
# 548                               E524
# 549                               E525
# 550                               E526
# 551                               E527
# 552                               E528
# 553                               E529
# 554                               E530
# 555                               E551
# 556                               E552
# 557                              E553a
# 558                              E553b
# 559                               E554
# 560                               E555
# 561                               E556
# 562                               E559
# 563                               E570
# 564                               E574
# 565                               E575
# 566                               E576
# 567                               E577
# 568                               E578
# 569                               E620
# 570                               E621
# 571                               E622
# 572                               E623
# 573                               E624
# 574                               E625
# 575                               E626
# 576                               E627
# 577                               E628
# 578                               E629
# 579                               E630
# 580                               E631
# 581                               E632
# 582                               E633
# 583                               E634
# 584                               E635
# 585                               E640
# 586                               E900
# 587                               E901
# 588                               E902
# 589                               E903
# 590                               E904
# 591                               E920
# 592                               E938
# 593                               E939
# 594                               E941
# 595                               E942
# 596                               E948
# 597                               E949
# 598                               E950
# 599                               E951
# 600                               E952
# 601                               E953
# 602                               E954
# 603                               E955
# 604                               E957
# 605                               E959
# 606                               E960
# 607                               E961
# 608                               E962
# 609                               E965
# 610                               E966
# 611                               E967
# 612                               E968
# 613                               E969
# 734     Hydroxypropyl Méthyl Cellulose
# 774                 Citrate de calcium
# 820                               E421
# 866                 Vinaigre d''Alcool
# 883                             Stévia
# 1097                              E127
# 1165                         Carbomère
# Name: INGA_LIBELLE, dtype: object

# %%
pd.set_option('display.max_rows', 10)

def remove_prefix(name):
    return name.lower().replace("arôme", "").replace("-","").strip()

arome_df = ingredient_df[(type_and_activity['type'] == "Arôme")]['INGA_LIBELLE'].apply(lambda x: remove_prefix(x))
arome_df.value_counts()
# les arômes grenadine et agrumes sont présents 2 fois
# Out:
# INGA_LIBELLE
# grenadine     2
# agrumes       2
# café          1
# tiramisu      1
# thym          1
#              ..
# kiwi          1
# canneberge    1
# abricot       1
# biscuit       1
# violette      1
# Name: count, Length: 98, dtype: int64

# %%
# TODO: 1 seule description pour l'arome réglisse dont la description est "arôme"

# %%
pd.set_option('display.max_rows', 100)
arome_df.to_frame().sort_values(by=["INGA_LIBELLE"])
# naturel  citron vs citron
# fruits rouges et fruit rouge
# bergamote et de bergamote
# ethylvanilline vs vanille vs vanilline
# raisin blanc vs raisin rouge
# "arômes" https://compl-alim.beta.gouv.fr/element/956--ingredient--Ar%C3%B4mes
# et "arôme" https://compl-alim.beta.gouv.fr/element/798--ingredient--Ar%C3%B4me
# et "arôme naturel" https://compl-alim.beta.gouv.fr/element/739--ingredient--Ar%C3%B4me%20naturel
# Out:
#                INGA_LIBELLE
# 797
# 780                 abricot
# 843                 acérola
# 936                 agrumes
# 901                 agrumes
# 948                  amande
# 761                  ananas
# 751                    anis
# 888                   baies
# 834                  banane
# 919                 basilic
# 1069              bergamote
# 778                 biscuit
# 768                   cacao
# 614                    café
# 781              canneberge
# 773                cannelle
# 615               cappucino
# 1018                  carvi
# 805                  cassis
# 766                  cerise
# 616                chocolat
# 617                  citron
# 818             citron vert
# 1055        clou de girofle
# 811                    coco
# 763                    cola
# 1028              concombre
# 836                   crème
# 1053                cupuaçu
# 1068           de bergamote
# 1074               de kemfe
# 1044         ethylvanilline
# 772              eucalyptus
# 1019                fenouil
# 857        fleur d''oranger
# 618                  fraise
# 756               framboise
# 1040  framboise  canneberge
# 916     fruit de la passion
# 731          fruit des bois
# 1011        fruit du dragon
# 757         fruit fantaisie
# 814             fruit rouge
# 849          fruit tropical
# 904                  fruits
# 845        fruits exotiques
# 813           fruits rouges
# 1005              genévrier
# 886                 grenade
# 747               grenadine
# 771               grenadine
# 794                    kiwi
# 1049                lavande
# 1036              mandarine
# 748                  mangue
# 833                   melon
# 746                  menthe
# 962                    miel
# 619                   mocca
# 620                myrtille
# 795                    mûre
# 1010              naringine
# 738                 naturel
# 753         naturel  citron
# 770                noisette
# 837            noix de coco
# 621                  orange
# 1045                 origan
# 891            pamplemousse
# 937                 passion
# 848                pastèque
# 989       pin des montagnes
# 917             pina colada
# 839                pistache
# 759            pistachecoco
# 812                   poire
# 988             poivre noir
# 765                   pomme
# 1042                pruneau
# 847        punch aux fruits
# 865                   pêche
# 947            raisin blanc
# 1076           raisin rouge
# 1017                romarin
# 1035                   rose
# 954                réglisse
# 955                       s
# 990                    thym
# 852                     thé
# 1043               thé vert
# 1041               thépêche
# 1001               tiramisu
# 622                 vanille
# 623               vanilline
# 1066               verveine
# 1090               violette
# 864                  yaourt
# 1077            ylang ylang
# 911                  épices

# %% [markdown]
# ### Activité spécifiée dans les déclarations

# %%
# En pratique, comment est utilisé cette possibilité d'activité/non activité dans les déclarations

ingr_declare_df = pd.read_csv("../../decla-data/ICA_INGREDIENT.csv", encoding="utf-16")
ingr_declare_df[['TYING_IDENT', 'FCTINGR_IDENT']].groupby(['TYING_IDENT', 'FCTINGR_IDENT']).value_counts().to_frame()
# les types correspondants sont dans REF_ICA_TYPE_INGREDIENT

TYPE_INGR_DECLA = {
    1: "Plantes",
    2: "Micro-organismes",
    3: "Autres ingrédients"
}
# Out:
#                             count
# TYING_IDENT FCTINGR_IDENT
# 1           1              202321
#             2                5448
# 2           1               15859
#             2                  47
# 3           1              233903
#             2              300774

# %%
ingr_declare_df
# Out:
#         INGR_IDENT  VRSDECL_IDENT  FCTINGR_IDENT  TYING_IDENT  \
# 0                1              4              2            3
# 1                2              4              1            3
# 2                3              4              1            3
# 3                4              4              1            3
# 4                5              4              1            3
# ...            ...            ...            ...          ...
# 758347      759764         167827              1            1
# 758348      759765         167827              1            1
# 758349      759766         167827              1            1
# 758350      759767         167827              1            1
# 758351      759768         167827              1            1
#
#         INGR_COMMENTAIRES
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 758347                NaN
# 758348                NaN
# 758349                NaN
# 758350                NaN
# 758351                NaN
#
# [758352 rows x 5 columns]

# %%
jointure_ingr_declare_ingr_reference = pd.read_csv("../../decla-data/ICA_INGREDIENT_AUTRE.csv", encoding="utf-16")
jointure_ingr_declare_ingr_reference
# il y a aussi une jointure pour les plantes et les micro-organismes ?
# ICA_MICRO_ORGANISME pour les Moorg
# ICA_PREPARATION pour les Plantes
# Out:
#         INGR_IDENT  INGA_IDENT
# 0             5955         691
# 1             6016         691
# 2             6053         691
# 3            14634         691
# 4            16501         691
# ...            ...         ...
# 534672      732764        1885
# 534673      750470        1886
# 534674      751309        1887
# 534675      751350        1887
# 534676      753077        1887
#
# [534677 rows x 2 columns]

# %%
declaration_with_ingredient_id_df = jointure_ingr_declare_ingr_reference.merge(ingr_declare_df, on="INGR_IDENT", how="left") # on INGR_IDENT
declaration_with_ingredient_id_df
# Out:
#         INGR_IDENT  INGA_IDENT  VRSDECL_IDENT  FCTINGR_IDENT  TYING_IDENT  \
# 0             5955         691           1827              1            3
# 1             6016         691           1831              1            3
# 2             6053         691           1897              1            3
# 3            14634         691           4104              1            3
# 4            16501         691           6464              1            3
# ...            ...         ...            ...            ...          ...
# 534672      732764        1885         160956              1            3
# 534673      750470        1886         164205              2            3
# 534674      751309        1887         165472              1            3
# 534675      751350        1887         165470              1            3
# 534676      753077        1887         166000              1            3
#
#         INGR_COMMENTAIRES
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 534672                NaN
# 534673                NaN
# 534674                NaN
# 534675                NaN
# 534676                NaN
#
# [534677 rows x 6 columns]

# %%
ingredient_df
# Out:
#       INGA_IDENT  STINGSBS_IDENT  TAING_IDENT  FCTINGR_IDENT  \
# 0            691               1            1              1
# 1            692               1            1              1
# 2            693               1            1              1
# 3            694               1            1              1
# 4            695               1            1              1
# ...          ...             ...          ...            ...
# 1168        1883               1            4              1
# 1169        1884               1            4              1
# 1170        1885               1            4              1
# 1171        1886               1            5              2
# 1172        1887               1            1              1
#
#                                         INGA_LIBELLE       INGA_LIBELLE_EN  \
# 0                         5'-déoxyadénosylcobalamine                   NaN
# 1                          6-palmitate de L-ascorbyl                   NaN
# 2                                 Acétate de calcium                   NaN
# 3                     Acétate de D-alpha-tocophéryle                   NaN
# 4                    Acétate de DL-alpha-tocophéryle                   NaN
# ...                                              ...                   ...
# 1168  isoflavones issues de Glycine max. (L.) Merr.            isoflavones
# 1169                         acide gamma-linolénique  gamma-linolenic acid
# 1170                                 Huile de hareng           Herring oil
# 1171                                 Lactose anhydre     Anhydrous Lactose
# 1172                            Sulfate de magnésium     magnesium sulfate
#
#      INGA_OBSERVATION INGA_COMMENTAIRE_PUBLIC INGA_COMMENTAIRE_PUBLIC_EN  \
# 0                 NaN                     NaN                        NaN
# 1                 NaN                     NaN                        NaN
# 2                 NaN                     NaN                        NaN
# 3                 NaN                     NaN                        NaN
# 4                 NaN                     NaN                        NaN
# ...               ...                     ...                        ...
# 1168              NaN                     NaN                        NaN
# 1169              NaN                     NaN                        NaN
# 1170              NaN                     NaN                        NaN
# 1171              NaN                     NaN                        NaN
# 1172              NaN                     NaN                        NaN
#
#                                  INGA_COMMENTAIRE_PRIVE  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1168    https://www.efsa.europa.eu/fr/press/news/151021
# 1169                                                NaN
# 1170                                                NaN
# 1171  Utilisation du lactose anhydre dans le domaine...
# 1172                                                NaN
#
#      INGA_COMMENTAIRE_PRIVE_EN INGA_DESCRIPTION INGA_DESCRIPTION_EN  \
# 0                          NaN              NaN                 NaN
# 1                          NaN              NaN                 NaN
# 2                          NaN              NaN                 NaN
# 3                          NaN              NaN                 NaN
# 4                          NaN              NaN                 NaN
# ...                        ...              ...                 ...
# 1168                       NaN              NaN                 NaN
# 1169                       NaN              NaN                 NaN
# 1170                       NaN              NaN                 NaN
# 1171                       NaN              NaN                 NaN
# 1172                       NaN              NaN                 NaN
#
#       INGA_ORDRE  INGA_OBSOLET
# 0            NaN         False
# 1            NaN         False
# 2            NaN         False
# 3            NaN         False
# 4            NaN         False
# ...          ...           ...
# 1168         NaN         False
# 1169         NaN         False
# 1170         NaN         False
# 1171         NaN         False
# 1172         NaN         False
#
# [1173 rows x 15 columns]

# %%
decla_with_ingredient = declaration_with_ingredient_id_df.merge(ingredient_df, on="INGA_IDENT", how="left", suffixes=("_declared", "_in_reference")) # on INGA_IDENT
decla_with_ingredient
# Out:
#         INGR_IDENT  INGA_IDENT  VRSDECL_IDENT  FCTINGR_IDENT_declared  \
# 0             5955         691           1827                       1
# 1             6016         691           1831                       1
# 2             6053         691           1897                       1
# 3            14634         691           4104                       1
# 4            16501         691           6464                       1
# ...            ...         ...            ...                     ...
# 534672      732764        1885         160956                       1
# 534673      750470        1886         164205                       2
# 534674      751309        1887         165472                       1
# 534675      751350        1887         165470                       1
# 534676      753077        1887         166000                       1
#
#         TYING_IDENT  INGR_COMMENTAIRES  STINGSBS_IDENT  TAING_IDENT  \
# 0                 3                NaN               1            1
# 1                 3                NaN               1            1
# 2                 3                NaN               1            1
# 3                 3                NaN               1            1
# 4                 3                NaN               1            1
# ...             ...                ...             ...          ...
# 534672            3                NaN               1            4
# 534673            3                NaN               1            5
# 534674            3                NaN               1            1
# 534675            3                NaN               1            1
# 534676            3                NaN               1            1
#
#         FCTINGR_IDENT_in_reference                INGA_LIBELLE  \
# 0                                1  5'-déoxyadénosylcobalamine
# 1                                1  5'-déoxyadénosylcobalamine
# 2                                1  5'-déoxyadénosylcobalamine
# 3                                1  5'-déoxyadénosylcobalamine
# 4                                1  5'-déoxyadénosylcobalamine
# ...                            ...                         ...
# 534672                           1             Huile de hareng
# 534673                           2             Lactose anhydre
# 534674                           1        Sulfate de magnésium
# 534675                           1        Sulfate de magnésium
# 534676                           1        Sulfate de magnésium
#
#           INGA_LIBELLE_EN INGA_OBSERVATION INGA_COMMENTAIRE_PUBLIC  \
# 0                     NaN              NaN                     NaN
# 1                     NaN              NaN                     NaN
# 2                     NaN              NaN                     NaN
# 3                     NaN              NaN                     NaN
# 4                     NaN              NaN                     NaN
# ...                   ...              ...                     ...
# 534672        Herring oil              NaN                     NaN
# 534673  Anhydrous Lactose              NaN                     NaN
# 534674  magnesium sulfate              NaN                     NaN
# 534675  magnesium sulfate              NaN                     NaN
# 534676  magnesium sulfate              NaN                     NaN
#
#        INGA_COMMENTAIRE_PUBLIC_EN  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 534672                        NaN
# 534673                        NaN
# 534674                        NaN
# 534675                        NaN
# 534676                        NaN
#
#                                    INGA_COMMENTAIRE_PRIVE  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 534672                                                NaN
# 534673  Utilisation du lactose anhydre dans le domaine...
# 534674                                                NaN
# 534675                                                NaN
# 534676                                                NaN
#
#        INGA_COMMENTAIRE_PRIVE_EN INGA_DESCRIPTION INGA_DESCRIPTION_EN  \
# 0                            NaN              NaN                 NaN
# 1                            NaN              NaN                 NaN
# 2                            NaN              NaN                 NaN
# 3                            NaN              NaN                 NaN
# 4                            NaN              NaN                 NaN
# ...                          ...              ...                 ...
# 534672                       NaN              NaN                 NaN
# 534673                       NaN              NaN                 NaN
# 534674                       NaN              NaN                 NaN
# 534675                       NaN              NaN                 NaN
# 534676                       NaN              NaN                 NaN
#
#         INGA_ORDRE  INGA_OBSOLET
# 0              NaN         False
# 1              NaN         False
# 2              NaN         False
# 3              NaN         False
# 4              NaN         False
# ...            ...           ...
# 534672         NaN         False
# 534673         NaN         False
# 534674         NaN         False
# 534675         NaN         False
# 534676         NaN         False
#
# [534677 rows x 20 columns]

# %%
decla_with_ingredient[["INGA_IDENT", "FCTINGR_IDENT_declared", "FCTINGR_IDENT_in_reference"]]
decla_with_ingredient['FCTINGR_IDENT_declared'].equals(decla_with_ingredient['FCTINGR_IDENT_in_reference'])
# les 2 colonnes ne sont pas égales
# Out:
# False

# %%
decla_with_ingredient['same_activity'] = np.where((decla_with_ingredient['FCTINGR_IDENT_declared'] == decla_with_ingredient['FCTINGR_IDENT_in_reference']), True, False)
len(decla_with_ingredient[decla_with_ingredient['same_activity'] == False]['INGA_LIBELLE'].unique())
# 518 ingrédients n'ont pas la même activité déclarée que celle dans la table de référence
# Out:
# 518

# %%
decla_with_ingredient[decla_with_ingredient['same_activity'] == False]['INGA_LIBELLE'].unique()
# Out:
# array(['6-palmitate de L-ascorbyl', 'Acétate de D-alpha-tocophéryle',
#        'Acétate de DL-alpha-tocophéryle', 'Acétate de rétinyle',
#        'Acétyl-taurinate de magnésium',
#        'acide (6S)-5-méthyltétrahydrofolique sous forme de sel de glucosamine',
#        'Acide L-ascorbique', 'Acide ptéroylmonoglutamique',
#        'Acide silicique', 'Ascorbate de manganèse', 'Béta-carotène',
#        'Bicarbonate de potassium', 'Bicarbonate de sodium',
#        'Bisglycinate de calcium', 'Bisglycinate de magnésium',
#        'Bisglycinate de zinc', 'Borate de sodium', 'Carbonate de calcium',
#        'Carbonate de cuivre', 'Carbonate de magnésium',
#        'Carbonate de manganèse', 'Carbonate de potassium',
#        'Carbonate de sodium', 'Carbonate de zinc',
#        'Chlorhydrate de pyridoxine', 'Chlorhydrate de thiamine',
#        'Chlorure de chrome', 'Chlorure de magnésium',
#        'Chlorure de potassium', 'Chlorure de sodium', 'Cholécalciférol',
#        'Citrate de manganèse', 'Citrate de potassium',
#        'Citrate de potassium - magnésium', 'Citrate de sodium',
#        'Citrate de zinc', 'Citrate ferreux', 'Cyanocobalamine',
#        'D-alpha-tocophérol', 'D-biotine', 'Dioxyde de silicium',
#        'DL-alpha-tocophérol', 'D-pantothénate de calcium',
#        'Fer élémentaire', 'Fluorure de calcium', 'Fumarate ferreux',
#        'Gluconate de calcium', 'Gluconate de cuivre',
#        'Gluconate de magnésium', 'Gluconate de manganèse',
#        'Gluconate de potassium', 'Gluconate de zinc', 'Gluconate ferreux',
#        'Glycérophosphate de calcium', 'Glycérophosphate de magnésium',
#        'Hydroxyde de calcium', 'Hydroxyde de magnésium',
#        'Hydroxyde de potassium', 'Hydroxyde de sodium',
#        'Iodate de potassium', 'Iodure de potassium', 'Lactate de calcium',
#        'L-ascorbate de calcium', 'L-ascorbate de sodium',
#        'L-aspartate de zinc', 'L-pidolate de magnésium',
#        'L-sélénométhionine', 'Malate de calcium', 'Malate de magnésium',
#        'Mélange de tocophérols', 'Ménaquinone', 'Molybdate de sodium',
#        'Mononitrate de thiamine', 'Nicotinamide', 'Oxyde de calcium',
#        'Oxyde de magnésium', 'Oxyde de zinc', 'Palmitate de rétinyle',
#        'Phosphate ferreux', 'Phylloquinone', 'Riboflavine',
#        'Sélénite de sodium', "Sels calciques de l'acide citrique",
#        "Sels calciques de l'acide orthophosphorique",
#        "Sels de magnésium de l'acide citrique",
#        "Sels de magnésium de l'acide orthophosphorique",
#        'Succinate acide de D-alpha-tocophéryle', 'Sulfate de cuivre',
#        'Sulfate de de magnésium', 'Sulfate de manganèse',
#        'Sulfate de potassium', 'Sulfate de zinc', 'Sulfate ferreux',
#        'Tocotriénol tocophérol', 'Acétylcarnitine',
#        "Acide adénosine-5'-phosphorique", 'Acide aspartique',
#        'Acide linoléique conjugué', 'Acide lipoïque',
#        'Acide para-aminobenzoïque', 'Acide pyruvique', 'Alanine',
#        'Amylase', 'Arabinogalactanes', 'Arginine', 'Bêta-alanine',
#        'Bêta-cyclodextrine', 'Bêtaglucanes', 'Bitartrate de choline',
#        'Bromélaïne', 'Caféine', 'Caséine',
#        "Chlorhydrate d'ester éthylique de créatine",
#        'Chlorure de choline', 'Citrate de choline', 'Créatine',
#        'Créatine monohydrate', 'Curcumine', 'Fructo-oligosaccharides',
#        'Galacto-oligosaccharides', 'Gelée royale',
#        'Gluconate de créatine', 'Glutamine', 'Glycine', 'Hespéridine',
#        'Histidine', 'Huile de poisson', 'Hydrolysat de protéines',
#        'Hydrolysat de protéines de lactosérum', 'Hydroxyméthylbutyrate',
#        'Hydroxytyrosol', 'Inosine', 'Inositol', 'Inuline',
#        'Isolat de protéine de lait', 'Isoleucine', 'Isomaltulose',
#        'Lactase', 'Lactosérum', 'L-carnitine', 'Lécithine', 'Leucine',
#        'Lutéine', 'Lycopène', 'Lysine', 'Mannitol', 'Minéraux du lait',
#        'Monohydrate de créatine', 'Oligofructose', 'Papaïne', 'Pectinase',
#        'Pectines', 'Phosphatidylcholine', 'Phosphatidylsérine',
#        'Phospholipides', 'Phycocyanine', 'Pollen', 'Poudre de lactosérum',
#        "Poudre d'œuf entier", 'Protéase', 'Protéine de lactosérum',
#        'Protéine de lait', 'Protéine de petit-lait', 'Protéine de soja',
#        'Protéines', 'Resvératrol', 'Ribose', 'Saccaharase', 'Sucrase',
#        'Sulfate de chondroïtine', 'Sulfate de glucosamine', 'Taurine',
#        'Triglycérides à chaine moyenne', 'Tyrosine', 'Ubiquinone',
#        'Valine', 'Xylanase', 'E101', 'E1200', 'E1201', 'E122', 'E140',
#        'E141', 'E1450', 'E150d', 'E153', 'E160a', 'E160c', 'E161b',
#        'E162', 'E163', 'E170', 'E171', 'E172', 'E202', 'E296', 'E300',
#        'E301', 'E302', 'E304', 'E306', 'E307', 'E322', 'E327', 'E330',
#        'E331', 'E332', 'E333', 'E334', 'E339', 'E340', 'E341', 'E343',
#        'E352', 'E401', 'E404', 'E406', 'E410', 'E412', 'E413', 'E414',
#        'E415', 'E420', 'E422', 'E425', 'E440', 'E450', 'E451', 'E459',
#        'E460', 'E463', 'E464', 'E468', 'E470a', 'E470b', 'E471', 'E500',
#        'E501', 'E504', 'E508', 'E511', 'E524', 'E526', 'E528', 'E530',
#        'E551', 'E552', 'E553a', 'E559', 'E570', 'E575', 'E640', 'E900',
#        'E904', 'E920', 'E950', 'E951', 'E952', 'E954', 'E955', 'E960',
#        'E965', 'E967', 'E968', 'arôme - café', 'arôme - chocolat',
#        'arôme - citron', 'arôme - fraise', 'arôme - myrtille',
#        'arôme - orange', 'arôme - vanille', 'amidon', 'amidon de maïs',
#        'amidon de riz', 'dextrose', 'dextrose-glucose', 'eau',
#        'extrait de malt', 'farine', "farine d'avoine", 'farine de blé',
#        'farine de riz', 'fécule de pomme de terre',
#        "filtrat d'eau argileuse", 'fructose', 'gélatine', 'glucose',
#        'huile de colza', 'huile de coton', 'huile de foie de morue',
#        'huile de morue', 'huile de noix de coco fractionnée',
#        'huile de riz', 'huile de sésame', 'huile de soja',
#        'huile de TCM (triglycérides à chaînes moyennes)',
#        'huile de tournesol', "huile d'olive", "huile d'onagre",
#        'huile végétale', "jus d'abricots", "jus d'ananas",
#        'jus de carotte', 'jus de citron', 'jus de fruits', 'jus de poire',
#        'jus de pomme', 'jus de raisin', "jus d'orange", 'lactose', 'lait',
#        'levure', 'malt', 'maltodextrine', 'menthol', 'miel',
#        'polysaccharose', 'poudre de cacao', 'poudre de cacao maigre',
#        "poudre de zeste d'orange", 'purée de goyave', 'purée de mangue',
#        'purée de papaye', 'purée de pomme', 'saccharose', 'sel',
#        'sel marin', "sirop d'agave", 'sirop de blé', 'sirop de glucose',
#        'sirop de manioc', 'sirop de riz déshydraté', 'sirop de tapioca',
#        'sucre', 'sucre de canne', 'vinaigre de pomme', 'yaourt',
#        'hydrolysat de poisson', 'monostearate de glycerol', 'Propolis',
#        'Collagène hydrolysé', 'Hydroxypropyl Méthyl Cellulose',
#        'Arôme naturel', 'Eau purifiée', 'Gelée royale lyophilisée',
#        'Vin rouge', 'Fibres de pomme',
#        'N,N-Diméthylglycine hydrochloride', 'Amidon de pomme de terre',
#        'Arôme - mangue', 'L-Arginine-alpha-cétoglutarate',
#        'L-Carnitine L-Tartrate ', 'Charbon végétal', 'Rutine ',
#        'Collagène marin', 'Arôme - framboise', 'Gélule végétale',
#        'Arôme - ananas', 'Poudre de fraise', 'Poudre de cannelle',
#        'Arôme - pomme', 'Protéine de pois', 'Arôme - cannelle',
#        'Citrate de calcium', 'Eau de mer', 'Arôme - canneberge',
#        'Gélatine de poisson', "Fibres solubles d''acacia",
#        'Huile de coprah', 'Son de riz', 'Nacre',
#        'Protéines de lactosérum', 'Poudre de calcium de corail', 'Alcool',
#        'dextrine', 'Arôme', 'Jus de betterave', 'Fibres',
#        'Fibres solubles', 'Fibres insolubles', 'Fibres solubles de maïs',
#        "Poudre de blanc d''oeuf", "Poudre blanc d''oeuf",
#        'Caséinate de calcium', 'Arôme - fruits rouges',
#        'Jus de pomme grenade', 'Jus de cerise', 'huile de germes de blé',
#        'Jus de grenade', 'Huile de périlla', 'Huile de coco',
#        'Eau osmosée dynamisée', 'Protéines de petit lait',
#        'Jus de cassis', 'Arôme - acérola', 'Cellulase',
#        'Huile de germe de maïs', 'Vinaigre de cidre',
#        'Coquille d’huître ', "miel d''acacia", 'miel d’acacia',
#        'Jus de myrtille', 'Jus de canneberge ', 'L-cystine',
#        'L-citrulline malate', 'Arôme - guarana',
#        'Argile verte montmorillonite', 'Hydromel', 'Alcool éthylique',
#        'Gélatine marine', 'Extrait de riz', '5-hydroxytryptophane',
#        'Jus de sureau', 'Dolomite', 'Cartilage de raie',
#        'Arôme - grenade', 'Arôme - baies', 'inositolhéxaphosphate',
#        "Jaune d''oeuf", 'Arôme - pamplemousse', 'Poudre de cerise',
#        'Serrapeptase', 'Eau potable', 'Jus de carotte violette',
#        'Acide L-malique', 'L-Glutamine', 'Cognac', 'Eau de roche',
#        'Amidon de blé ', 'Arôme - fruit de la passion', 'tréhalose',
#        'Chlorhydrate de lysine', 'Sels Thermaux de Vichy',
#        'Jus de pruneau', 'Jus de framboise', "Cire d''abeille",
#        'Hydrolysat enzymatique de protéines de riz', 'Hémicellulase',
#        'Argile blanche', 'Huile de graine de lin',
#        'Jus concentré de figue', 'Cosse de riz',
#        'Proteine de blé hydrolysée', 'Nattokinase', "Fibres d''agrumes",
#        'Hyaluronate de sodium', 'Chlorophylle',
#        'Chlorhydrate de L-ornithine', 'Gamma-cyclodextrine', 'Réglisse',
#        'huile de palmiste', 'Levure de bière inactivée',
#        'Huile de foie de morues', 'Citroflavonoïdes',
#        'Hydrolysat des protéines bovines',
#        'Hydrolysat de protéines de poulet', 'Alpha-cyclodextrine',
#        'Huile anchois - sardine', 'Chlorhydrate de L-Histidine',
#        'Jus de pamplemousse', 'L-isoleucine', 'L-leucine', 'L-valine',
#        'Collagène', 'Farine de quinoa', 'Anas barbariae',
#        'Pectine de pomme', 'Arôme - Poivre noir', 'Arôme - thym',
#        'Eau de coco en poudre', 'Purée de betterave', 'lait de chamelle',
#        'Sirop érable', 'jus de griotte', 'jus de groseille',
#        'jus de mûre', 'Arôme - Genévrier', 'Jus de prune',
#        'Poudre de pomme', 'Arôme - naringine', 'Huile de carthame',
#        'huile de saumon ', 'Moule perlière d eau douce',
#        'Huile de cameline', 'poudre de betterave', 'poudre de citron',
#        'Jus de pêche', 'Arôme - thé vert', 'Arôme - origan',
#        'Peptides de poisson', "Fibres d'avoine", 'eau de source',
#        'arôme clou de girofle', 'Fibres solubles de fenugrec',
#        'Concentré de spiruline et carthame',
#        'Huile de bourrache (borago officinalis)', 'Acide férulique',
#        'Farine de soja', 'arôme - raisin rouge', 'Protéines de riz',
#        'Caséinate de sodium', 'Hydrolysat de collagène bovin',
#        'Hydrolysat de collagène de poisson', 'farine de banane verte',
#        'amidon de maïs modifié', 'Fécule de maïs', 'Caroténoïdes',
#        'Concentre de carotte et pomme', 'concentré de carotte et cassis',
#        'Beurre', 'Mélange de légumes', 'Farine de noix de coco',
#        'miel de Manuka', "Jus d'acérola",
#        'Chlorophylline de cuivre sodique',
#        'Lactobacillus plantarum inactivé',
#        'Bifidobacterium lactis inactivée', 'Acide stéarique'],
#       dtype=object)

# %% [markdown]
# À discuter avec BEPIAS : est-ce que c'est vraiment pertinent de laisser les déclarants choisir l'activité des ingrédients ?
# Si un ingrédient est reconnu actif, pourquoi deviendrait-il soudainement inactif dans un certain type de préparation ?

# %%
# le type de l'ing déclaré TYING_IDENT et le type de l'ing de référence TAING_IDENT sont différents 
# TAING_IDENT est plus spécifique
decla_with_ingredient['type'] = decla_with_ingredient['TAING_IDENT']

# %%
decla_with_ingredient['type'] =
# Out:
#         INGR_IDENT  INGA_IDENT
# 0             5955         691
# 1             6016         691
# 2             6053         691
# 3            14634         691
# 4            16501         691
# ...            ...         ...
# 534672      732764        1885
# 534673      750470        1886
# 534674      751309        1887
# 534675      751350        1887
# 534676      753077        1887
#
# [534677 rows x 2 columns]
